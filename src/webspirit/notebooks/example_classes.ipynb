# %% [markdown]
# # Programmation Oriented Object
# ***

# %%
from webspirit.tools.checktype import CheckType, ValidatePathOrUrl, StrPath, HyperLink, PathOrURL

from webspirit.tools.contexterror import ErrorContextManager as ECM

from webspirit.tools.contexterror import ecm, raise_error, re

from webspirit.tools.introspection import show, exception

from webspirit.tools.csvmanager import CSVManager, Music

from webspirit.tools.jsonmanager import JSONManager

# %%
from webspirit.config.constants import LOGGER, PATH_LANGUAGES, PATH_MUSICS_LIST

from webspirit.config.logger import INFO, ERROR, WARNING, DEBUG

# %%
from os.path import abspath

# %%
# Configuration for the logger output
LOGGER.disabled = False

# Relative path
PATH_LANGUAGES, PATH_MUSICS_LIST = StrPath(PATH_LANGUAGES).relpath(), StrPath(PATH_MUSICS_LIST).relpath()

# %% [markdown]
# # *contexterror.py*

# %% [markdown]
# ## ErrorContextManager or *ecm*

# %%
@ECM("Error in the divide function 1") # or ecm
def divide(a: int, b: int) -> float:
    return a / b

divide(10, 0)
# Out:
# 2025-08-30 15:35:49  webspirit.config.logger  WARNING  Error in the divide function 1

# %%
@ecm("Error in the divide function 2", error=True)
def divide(a: int, b: int) -> float:
    return a / b

divide(10, 0)
# Out:
# 2025-08-30 15:35:49  webspirit.config.logger  WARNING  Error in the divide function 2
# Traceback (most recent call last):
#   File "C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tools\contexterror.py", line 28, in _function
#     return fonction(*args, **kwargs)
#   File "C:\Users\Blondel\AppData\Local\Temp\ipykernel_13412\2736032603.py", line 3, in divide
#     return a / b
#            ~~^~~
# ZeroDivisionError: division by zero

# %%
with ecm("Error in the block", WARNING):
    x = 1 / 0
# Out:
# 2025-08-30 15:35:49  webspirit.config.logger  WARNING  Error in the block

# %% [markdown]
# ## raise_error or *re*

# %%
with ecm("Error in the example function", error=True): # let=False
    raise_error("Something wrong", error=RuntimeError) # or re
# Out:
# 2025-08-30 15:35:49  webspirit.config.logger  ERROR    Something wrong
# 2025-08-30 15:35:49  webspirit.config.logger  WARNING  Error in the example function
# Traceback (most recent call last):
#   File "C:\Users\Blondel\AppData\Local\Temp\ipykernel_13412\926349046.py", line 2, in <module>
#     raise_error("Something wrong", error=RuntimeError) # or re
#     ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tools\contexterror.py", line 55, in raise_error
#     raise error(message)
# RuntimeError: Something wrong

# %% [markdown]
# # *checktype.py*

# %% [markdown]
# ## HyperLink

# %%
HyperLink.__mro__
# Out:
# (webspirit.tools.checktype.HyperLink,
#  str,
#  webspirit.tools.checktype._PathOrURL,
#  object)

# %% [markdown]
# ### Methods

# %%
HyperLink.is_url('https://youtu.be/kO8Nj09525U')
# Out:
# True

# %%
HyperLink.is_url(HyperLink('https://youtu.be/kO8Nj09525U'))
# Out:
# True

# %%
HyperLink.is_url('Hello Word!')
# Out:
# False

# %% [markdown]
# ### Examples

# %%
url = HyperLink('https://youtu.be/kO8Nj09525U')

# %%
show(url)
# Out:
# str  : https://youtu.be/kO8Nj09525U
# repr : HyperLink('https://youtu.be/kO8Nj09525U')

# %%
exception(HyperLink, string='https://')
# Out:
# 2025-08-30 15:35:49  webspirit.config.logger  ERROR    'https://' must be a valid hyperlink
# TypeError("'https://' must be a valid hyperlink")

# %%
id(url) == id(url.copy())
# Out:
# False

# %% [markdown]
# ## StrPath

# %%
StrPath.__mro__
# Out:
# (webspirit.tools.checktype.StrPath,
#  pathlib._local.Path,
#  pathlib._abc.PathBase,
#  pathlib._local.PurePath,
#  pathlib._abc.PurePathBase,
#  webspirit.tools.checktype._PathOrURL,
#  object)

# %% [markdown]
# ### Methods

# %%
PATH_LANGUAGES
# Out:
# StrPath('..\data\languages.csv')

# %%
StrPath.is_path(r"C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\data\languages.csv")
# Out:
# True

# %%
StrPath.is_path(str(PATH_LANGUAGES))
# Out:
# True

# %%
StrPath.is_path(StrPath(PATH_LANGUAGES))
# Out:
# True

# %%
StrPath.is_path(abspath(r'..\data\musics.csv'), suffix=('csv', 'txt'))
# Out:
# True

# %%
StrPath.is_path(abspath(r'..\data\musics.csv'), suffix='csv')
# Out:
# True

# %%
StrPath.is_path(abspath(r'..\data'), dir=True)
# Out:
# True

# %%
PATH_LANGUAGES.copy().absolute(), PATH_LANGUAGES.copy().relpath(), PATH_LANGUAGES.copy().dirname()
# Out:
# (StrPath('..\data\languages.csv'),
#  StrPath('..\data\languages.csv'),
#  StrPath('..\data'))

# %% [markdown]
# ### Examples

# %%
path = StrPath(PATH_LANGUAGES)

# %%
show(path)
# Out:
# str  : ..\data\languages.csv
# repr : StrPath('..\data\languages.csv')

# %%
exception(StrPath, string=r'..\src\data\musics.cpp')
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  ERROR    '..\src\data\musics.cpp' must be a valid path to a file or a directory
# TypeError("'..\\src\\data\\musics.cpp' must be a valid path to a file or a directory")

# %%
id(path) == id(path.copy())
# Out:
# False

# %% [markdown]
# ## CheckType & ValidatePathOrUrl

# %%
class BookOfLink:
    @CheckType()
    def append_url1(self, url: HyperLink, nbr: int) -> tuple[HyperLink, int]:
        return type(url), type(nbr)

    @CheckType()
    def append_url2(self, url: str, nbr: int | None = None) -> tuple[str, int | None]:
        return type(url), type(nbr)

    @CheckType('url', 'nbr', 'string')
    def append_url3(self, url: HyperLink, nbr: int, string: str) -> tuple[HyperLink, int, str]:
        return type(url), type(nbr), type(string)

    @CheckType('path')
    def append_path(self, path: StrPath) -> StrPath:
        return type(path)

    @ValidatePathOrUrl('link')
    def append1(self, link: PathOrURL = "https://youtu.be/_0Pf48RqSsg") -> PathOrURL:
        return type(link)

    @ValidatePathOrUrl('url')
    def append2(self, url: HyperLink) -> HyperLink:
        return type(url)

# %%
@CheckType()
def append_url1(url: HyperLink, nbr: int) -> tuple[HyperLink, int]:
    return type(url), type(nbr)

@CheckType()
def append_url2(url: str, nbr: int | None = None) -> tuple[str, int | None]:
    return type(url), type(nbr)

@CheckType('url', 'nbr', 'string')
def append_url3(url: HyperLink, nbr: int, string: str) -> tuple[HyperLink, int, str]:
    return type(url), type(nbr), type(string)

@CheckType('path')
def append_path(path: StrPath) -> StrPath:
    return type(path)

@ValidatePathOrUrl('link')
def append1(link: PathOrURL = "https://youtu.be/_0Pf48RqSsg") -> PathOrURL:
    return type(link)

@ValidatePathOrUrl('url')
def append2(url: HyperLink) -> HyperLink:
    return type(url)

# %% [markdown]
# ### CheckType

# %% [markdown]
# #### Class

# %%
book = BookOfLink()

# %%
book.append_url1('https://youtu.be/1V_xRb0x9aw', 7)
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change 'https://youtu.be/1V_xRb0x9aw' of type <class 'str'> to type <class 'webspirit.tools.checktype.HyperLink'>
# (webspirit.tools.checktype.HyperLink, int)

# %%
book.append_url2('https://youtu.be/1V_xRb0x9aw', '7')
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '7' of type <class 'str'> to type <class 'int'>
# (str, int)

# %%
book.append_url2('https://youtu.be/1V_xRb0x9aw')
# Out:
# (str, NoneType)

# %%
book.append_url3('https://youtu.be/1V_xRb0x9aw', '7', 190)
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change 'https://youtu.be/1V_xRb0x9aw' of type <class 'str'> to type <class 'webspirit.tools.checktype.HyperLink'>
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '7' of type <class 'str'> to type <class 'int'>
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '190' of type <class 'int'> to type <class 'str'>
# (webspirit.tools.checktype.HyperLink, int, str)

# %%
book.append_path(str(PATH_MUSICS_LIST))
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '..\data\musics.csv' of type <class 'str'> to type <class 'webspirit.tools.checktype.StrPath'>
# webspirit.tools.checktype.StrPath

# %%
exception(book.append_path, "data/musics.txt")
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  ERROR    'data/musics.txt' must be a valid path to a file or a directory
# 2025-08-30 15:35:50  webspirit.config.logger  ERROR    'path' object with 'data/musics.txt' value, can't be converted to <class 'webspirit.tools.checktype.StrPath'>
# ValueError("'path' object with 'data/musics.txt' value, can't be converted to <class 'webspirit.tools.checktype.StrPath'>")

# %% [markdown]
# #### Function

# %%
append_url1('https://youtu.be/1V_xRb0x9aw', 7)
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change 'https://youtu.be/1V_xRb0x9aw' of type <class 'str'> to type <class 'webspirit.tools.checktype.HyperLink'>
# (webspirit.tools.checktype.HyperLink, int)

# %%
append_url2('https://youtu.be/1V_xRb0x9aw', '7')
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '7' of type <class 'str'> to type <class 'int'>
# (str, int)

# %%
append_url2('https://youtu.be/1V_xRb0x9aw')
# Out:
# (str, NoneType)

# %%
append_url3('https://youtu.be/1V_xRb0x9aw', '7', 190)
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change 'https://youtu.be/1V_xRb0x9aw' of type <class 'str'> to type <class 'webspirit.tools.checktype.HyperLink'>
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '7' of type <class 'str'> to type <class 'int'>
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '190' of type <class 'int'> to type <class 'str'>
# (webspirit.tools.checktype.HyperLink, int, str)

# %%
append_path(str(PATH_MUSICS_LIST))
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '..\data\musics.csv' of type <class 'str'> to type <class 'webspirit.tools.checktype.StrPath'>
# webspirit.tools.checktype.StrPath

# %%
exception(append_path, "data/musics.txt")
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  ERROR    'data/musics.txt' must be a valid path to a file or a directory
# 2025-08-30 15:35:50  webspirit.config.logger  ERROR    'path' object with 'data/musics.txt' value, can't be converted to <class 'webspirit.tools.checktype.StrPath'>
# ValueError("'path' object with 'data/musics.txt' value, can't be converted to <class 'webspirit.tools.checktype.StrPath'>")

# %% [markdown]
# ### ValidatePathOrUrl

# %% [markdown]
# #### Class

# %%
book.append1(str(PATH_MUSICS_LIST))
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '..\data\musics.csv' of type <class 'str'> to type <class 'webspirit.tools.checktype.StrPath'>
# webspirit.tools.checktype.StrPath

# %%
book.append2("https://youtu.be/1V_xRb0x9aw")
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change 'https://youtu.be/1V_xRb0x9aw' of type <class 'str'> to type <class 'webspirit.tools.checktype.HyperLink'>
# webspirit.tools.checktype.HyperLink

# %% [markdown]
# #### Function

# %%
append1(str(PATH_MUSICS_LIST))
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change '..\data\musics.csv' of type <class 'str'> to type <class 'webspirit.tools.checktype.StrPath'>
# webspirit.tools.checktype.StrPath

# %%
append2("https://youtu.be/1V_xRb0x9aw")
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change 'https://youtu.be/1V_xRb0x9aw' of type <class 'str'> to type <class 'webspirit.tools.checktype.HyperLink'>
# webspirit.tools.checktype.HyperLink

# %% [markdown]
# # *jsonmanager.py*

# %%
#JSONManager.load()

# %% [markdown]
# # *csvmanager.py*

# %% [markdown]
# ## Music

# %%
Music.__mro__
# Out:
# (webspirit.tools.csvmanager.Music, object)

# %%
music = Music('https://youtu.be/kO8Nj09525U')
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  DEBUG    Change 'https://youtu.be/kO8Nj09525U' of type <class 'str'> to type <class 'webspirit.tools.checktype.HyperLink'>

# %%
show(music)
# Out:
# str  : https://youtu.be/kO8Nj09525U
# repr : Music(youtube_url=HyperLink('https://youtu.be/kO8Nj09525U'), path=None, extension=None, type=None, spotify_url=None, picture=None, meta=None)

# %%
youtube_url, path, extension, type, spotify_url, picture, meta = music

# %%
youtube_url, path, extension, type, spotify_url, picture, meta
# Out:
# (HyperLink('https://youtu.be/kO8Nj09525U'), None, None, None, None, None, None)

# %% [markdown]
# ## CSVManager

# %% [markdown]
# ### Methods

# %%
csv = CSVManager(PATH_LANGUAGES, headers=None)
# Out:
# 2025-08-30 15:35:50  webspirit.config.logger  INFO     Load 'languages.csv' in '..\data'
# 2025-08-30 15:35:50  webspirit.config.logger  INFO     Save the DataFrame in '..\data\languages.csv'

# %%
csv.path.relpath()
# Out:
# StrPath('..\data\languages.csv')

# %%
csv.length, csv.width
# Out:
# (2, 157)

# %%
csv.size
# Out:
# (2, 157)

# %%
csv
# Out:
# CSVManager(path=..\data\languages.csv, length=2, width=157)

# %% [markdown]
# ### Examples

# %%
csv = CSVManager()
# Out:
# 2025-08-30 15:35:51  webspirit.config.logger  DEBUG    Create C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tmp\tmp_musics.csv, because doesn't exist
# 2025-08-30 15:35:51  webspirit.config.logger  DEBUG    Change 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tmp\tmp_musics.csv' of type <class 'pathlib._local.WindowsPath'> to type <class 'webspirit.tools.checktype.StrPath'>
# 2025-08-30 15:35:51  webspirit.config.logger  INFO     Load 'tmp_musics.csv' in '..\tmp'
# 2025-08-30 15:35:51  webspirit.config.logger  INFO     Save the DataFrame in '..\tmp\tmp_musics.csv'

# %%
repr(csv)
# Out:
# 'CSVManager(path=..\\tmp\\tmp_musics.csv, length=7, width=0)'

# %%
csv.append(PATH_MUSICS_LIST)
# Out:
# 2025-08-30 15:35:51  webspirit.config.logger  INFO     Load '..\data\musics.csv' in '..\data'
# 2025-08-30 15:35:51  webspirit.config.logger  INFO     Save the DataFrame in '..\tmp\tmp_musics.csv'

# %%
repr(csv)
# Out:
# 'CSVManager(path=..\\tmp\\tmp_musics.csv, length=7, width=25)'

# %%
csv
# Out:
# CSVManager(path=..\tmp\tmp_musics.csv, length=7, width=25)

# %%
csv.append(r"C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\YouTubeDownloader\src\ytload\data\musics_copy.csv")
# Out:
# 2025-08-30 15:35:51  webspirit.config.logger  ERROR    'resource' object with 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\YouTubeDownloader\src\ytload\data\musics_copy.csv' must be a valid url or a path to a csv or a txt file
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 csv.append(r"C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\YouTubeDownloader\src\ytload\data\musics_copy.csv")
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tools\checktype.py:128, in CheckType.__call__.<locals>.wrapper(cls, *args, **kwargs)
#     126         if parameter in arguments:
#     127             asked, given = self.annotations[parameter], arguments[parameter]
# --> 128             self.validate_and_convert_type(given, asked, parameter, bound)
#     130 return self.function(*bound.args, **bound.kwargs)
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tools\checktype.py:136, in CheckType.validate_and_convert_type(self, given, asked, parameter, bound)
#     134 def validate_and_convert_type(self, given: object, asked: type, parameter: str, bound: BoundArguments):
#     135     if type(given) != asked and self._convert:
# --> 136         bound.arguments[parameter] = self.convert(parameter, bound.arguments[parameter], self.annotations[parameter])
#     138     elif type(given) != asked:
#     139         _re(f"For the '{parameter}' parameter, it must be of type {asked}, but you have given '{given}' with a type of {type(given)}")
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tools\checktype.py:186, in ValidatePathOrUrl.convert(self, parameter, value, annotation)
#     183     log(f"Change '{value}' of type {type(value)} to type {type(returned)}", DEBUG)
#     184     return returned
# --> 186 _re(f"'{parameter}' object with '{value}' must be a valid url or a path to a csv or a txt file", ValueError)
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\tools\contexterror.py:55, in raise_error(message, error, logger)
#      53 def raise_error(message: str = '', error: type = TypeError, logger: Logger = LOGGER):
#      54     log(message, ERROR, logger)
# ---> 55     raise error(message)
#
# ValueError: 'resource' object with 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\YouTubeDownloader\src\ytload\data\musics_copy.csv' must be a valid url or a path to a csv or a txt file

# %%
csv.size

# %%
exception(csv.append, 'https://youtu.be/-xmuUbw5vyc')

# %%
csv.delete()
