# %% [markdown]
# # [*typing.py*](../../../src/webspirit/classes/tools/typing.py)
#
# ***

# %%
from webspirit.classes.tools.typing import (
    __all__,
    HyperLink,
    StrPath,
    SuffixPath,
    JsonPath,
    CsvPath,
)
# Out:
# 2026-01-11 15:05:48   interactiveshell.py:3699  DEBUG    Init dir '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:05:48   interactiveshell.py:3699  DEBUG    Found checktype, contexterror, csvmanager, manager, typing modules and 0 directory in '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:05:49                 In[1]:1     WARNING  Failed to load one of these modules : checktype, contexterror, csvmanager, manager, typing
# 2026-01-11 15:05:49   interactiveshell.py:3639  DEBUG    Init dir '..\..\..\src\webspirit\classes'
# 2026-01-11 15:05:49   interactiveshell.py:3639  DEBUG    Found webfiles modules and tools directory in '..\..\..\src\webspirit\classes'
# 2026-01-11 15:05:49   interactiveshell.py:3699  DEBUG    Get attribute tools in ..\..\..\src\webspirit\classes\tools

# %%
__all__
# Out:
# ['HyperLink', 'StrPath', 'SuffixPath', 'JsonPath', 'CsvPath']

# %% [markdown]
# ## StrPath
# ***

# %%
path = StrPath('./typing.ipynb')

# %%
path.suffix
# Out:
# '.ipynb'

# %% [markdown]
# ## SuffixPath
# ***

# %%
path = SuffixPath('./typing.ipynb', '.ipynb') # or .ipynb or ['.ipynb'] or ['ipynb']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 path = SuffixPath('./typing.ipynb', '.ipynb') # or .ipynb or ['.ipynb'] or ['ipynb']
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\classes\tools\typing.py:111, in SuffixPath.__new__(cls, _, exist, *paths)
#     110 def __new__(cls, *paths: 'str | Path', _=None, exist: bool = True):
# --> 111     return super().__new__(cls, *paths)
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\classes\tools\typing.py:69, in StrPath.__new__(cls, exist, *paths)
#      66 string = paths[0] if len(paths) == 1 else Path(*paths)
#      68 if not (StrPath.is_path(string) or StrPath.is_path(string, dir=True)) and exist:
# ---> 69     _re(f"'{string}' must be a valid path to a file or a directory")
# ...

# %% [markdown]
# ### JsonPath & CsvPath
# ***

# %%
JsonPath('../data/jsonmanager_refuge.json', exist=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 JsonPath('../data/jsonmanager_refuge.json', exist=False)
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\classes\tools\typing.py:111, in SuffixPath.__new__(cls, _, exist, *paths)
#     110 def __new__(cls, *paths: 'str | Path', _=None, exist: bool = True):
# --> 111     return super().__new__(cls, *paths)
#
# File ~\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit\classes\tools\typing.py:69, in StrPath.__new__(cls, exist, *paths)
#      66 string = paths[0] if len(paths) == 1 else Path(*paths)
#      68 if not (StrPath.is_path(string) or StrPath.is_path(string, dir=True)) and exist:
# ---> 69     _re(f"'{string}' must be a valid path to a file or a directory")
#      71 return super().__new__(cls, *paths)
#
# ...
