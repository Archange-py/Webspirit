# %% [markdown]
# # [*typing.py*](../../classes/tools/typing.py)
#
# ***

# %%
from webspirit.classes import (
    __all__,
    HyperLink,
    StrPath,
    SuffixPath,
    JsonPath,
    CsvPath,
)
# Out:
# 2025-12-22 23:44:49   interactiveshell.py:3699  DEBUG    Init dir '..\..\classes\tools'
# 2025-12-22 23:44:49   interactiveshell.py:3699  DEBUG    Found checktype, contexterror, csvmanager, jsonmanager modules and 0 directory in '..\..\classes\tools'
# 2025-12-22 23:44:50   interactiveshell.py:3639  DEBUG    Init dir '..\..\classes'
# 2025-12-22 23:44:50   interactiveshell.py:3639  DEBUG    Found webfiles modules and tools directory in '..\..\classes'
# 2025-12-22 23:44:50   interactiveshell.py:3699  DEBUG    Get attribute tools in ..\..\classes\tools

# %%
__all__
# Out:
# ['HyperLink',
#  'StrPath',
#  'SuffixPath',
#  'JsonPath',
#  'CsvPath',
#  'CheckType',
#  'ErrorContextManager',
#  'ecm',
#  'raise_error',
#  're',
#  'Music',
#  'CSVManager',
#  'JSONManager',
#  'load_json',
#  'save_json']

# %% [markdown]
# ## StrPath
# ***

# %%
path = StrPath('./webfiles.ipynb', 'ok')

# %%
path.suffix
# Out:
# '.ipynb'

# %% [markdown]
# ## SuffixPath
# ***

# %%
path = SuffixPath('./webfiles.ipynb', '.ipynb') # or .ipynb or ['.ipynb'] or ['ipynb']

# %% [markdown]
# ### JsonPath & CsvPath
# ***

# %%
JsonPath('../data/jsonmanager_refuge.json', exist=False)
# Out:
# 2025-12-22 23:44:52   interactiveshell.py:3699  DEBUG    Skip existing test for '../data/jsonmanager_refuge.json'
# JsonPath('..\data\jsonmanager_refuge.json')
