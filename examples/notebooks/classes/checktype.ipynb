# %% [markdown]
# # [*checktype.py*](../../../src/webspirit/classes/tools/checktype.py)
#
# ***

# %%
from webspirit.classes.tools.checktype import (
    __all__,
    CheckType,
)
# Out:
# 2026-01-11 15:00:49   interactiveshell.py:3699  DEBUG    Init dir '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:00:49   interactiveshell.py:3699  DEBUG    Found checktype, contexterror, csvmanager, manager, typing modules and 0 directory in '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:00:50                 In[1]:1     WARNING  Failed to load one of these modules : checktype, contexterror, csvmanager, manager, typing
# 2026-01-11 15:00:50   interactiveshell.py:3639  DEBUG    Init dir '..\..\..\src\webspirit\classes'
# 2026-01-11 15:00:50   interactiveshell.py:3639  DEBUG    Found webfiles modules and tools directory in '..\..\..\src\webspirit\classes'
# 2026-01-11 15:00:50   interactiveshell.py:3699  DEBUG    Get attribute tools in ..\..\..\src\webspirit\classes\tools

# %%
__all__
# Out:
# ['CheckType']

# %% [markdown]
# ## CheckType

# %%
class Add:
    @CheckType
    def add(self, a: str, b: str) -> int:
        return a + b

# %%
A = Add()
A.add(1, 2)
# Out:
# 2026-01-11 15:00:50          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# 2026-01-11 15:00:50          checktype.py:118   DEBUG    Change the parameter a of add with a '1' value and a type <class 'int'> to type <class 'str'>
# 2026-01-11 15:00:50          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# 2026-01-11 15:00:50          checktype.py:118   DEBUG    Change the parameter b of add with a '2' value and a type <class 'int'> to type <class 'str'>
# '12'
