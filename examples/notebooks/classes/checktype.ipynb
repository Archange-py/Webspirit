# %% [markdown]
# # [*checktype.py*](../tools/checktype.py)
#
# ***

# %%
from webspirit.tools.checktype import (
    __all__,
    CheckType,
    HyperLink,
    StrPath,
)

# %%
__all__
# Out:
# ['HyperLink', 'StrPath', 'CheckType', 'StaticMethod', 'ValidatePathOrUrl']

# %% [markdown]
# ## CheckType

# %%
class Add:
    @CheckType
    def add(self, a: str, b: str) -> int:
        return a + b

# %%
A = Add()
A.add(1, 2)
# Out:
# 2025-10-02 17:29:48          checktype.py:213   DEBUG    Change the parameter a of add with a '1' value and a type <class 'int'> to type <class 'str'>
# 2025-10-02 17:29:48          checktype.py:213   DEBUG    Change the parameter b of add with a '2' value and a type <class 'int'> to type <class 'str'>
# '12'
