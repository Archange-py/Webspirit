# %% [markdown]
# # [*manager.py*](../../../src/webspirit/classes/tools/manager.py)
#
# ***

# %%
from webspirit.classes.tools.typing import StrPath

from webspirit.config.files_constants import (
    DIR_EXAMPLES_DATA,
    DIR_EXAMPLES_GENERATED,
)
# Out:
# 2025-12-29 18:37:09   interactiveshell.py:3699  DEBUG    Init dir '..\..\..\src\webspirit\classes\tools'
# 2025-12-29 18:37:09   interactiveshell.py:3699  DEBUG    Found checktype, contexterror, csvmanager, manager, typing modules and 0 directory in '..\..\..\src\webspirit\classes\tools'
# 2025-12-29 18:37:10   interactiveshell.py:3639  DEBUG    Init dir '..\..\..\src\webspirit\classes'
# 2025-12-29 18:37:10   interactiveshell.py:3639  DEBUG    Found webfiles modules and tools directory in '..\..\..\src\webspirit\classes'
# 2025-12-29 18:37:10   interactiveshell.py:3699  DEBUG    Get attribute tools in ..\..\..\src\webspirit\classes\tools

# %%
from webspirit.classes.tools.manager import (
    __all__,

    load_manager,

    BaseManager,

    JsonManager,
    load_json,
    save_json,
    delete_json,

    CsvManager,
)

# %%
__all__
# Out:
# ['ManagerMeta',
#  'BaseManager',
#  'load_manager',
#  'JsonManager',
#  'load_json',
#  'save_json',
#  'delete_json',
#  'CsvManager']

# %% [markdown]
# ## load_manager

# %%
path: StrPath = StrPath(DIR_EXAMPLES_DATA / 'jsonmanager_refuge.json')

# %%
loaded = load_manager(path)
# Out:
# 2025-12-29 18:37:11            manager.py:69    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:108   DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data'
# 2025-12-29 18:37:11          checktype.py:93    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:78    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:108   DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data'
# 2025-12-29 18:37:11            manager.py:99    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:108   DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data'
# 2025-12-29 18:37:11          checktype.py:93    INFO     Load 'jsonmanager_refuge.json' in '..\..\data' directory

# %%
type(loaded)
# Out:
# webspirit.classes.tools.manager.JsonManager

# %%
loaded
# Out:
# {'refuges': [{'accessible_hiver': False,
#    'altitude': 2151,
#    'altitude_m': 481,
#    'capacite': 75,
#    'coordonnees': {'latitude': 42.8025, 'longitude': -0.1417},
#    'nom': 'Refuge des Oulettes de Gaube',
#    'services': ['dortoir', 'repas', 'eau potable']},
#   {'accessible_hiver': True,
#    'altitude': 2651,
#    'capacite': 30,
#    'coordonnees': {'latitude': 42.7892, 'longitude': -0.1411},
#    'nom': 'Refuge de Bayssellance',
#    'services': ['dortoir', 'repas', 'eau potable', 'guide']},
#   {'accessible_hiver': False,
#    'altitude': 2571,
#    'capacite': 50,
#    'coordonnees': {'latitude': 42.7167, 'longitude': 0.5711},
#    'nom': 'Refuge du Portillon',
#    'services': ['dortoir', 'repas', 'eau potable', 'wifi']}]}

# %% [markdown]
# ## JsonManager

# %%
manager = JsonManager(path)

# %%
manager['refuges'][0]
# Out:
# {'accessible_hiver': False,
#  'altitude': 2151,
#  'altitude_m': 481,
#  'capacite': 75,
#  'coordonnees': {'latitude': 42.8025, 'longitude': -0.1417},
#  'nom': 'Refuge des Oulettes de Gaube',
#  'services': ['dortoir', 'repas', 'eau potable']}

# %%
from random import randint

manager['refuges'][0]['altitude_m'] = randint(0, 3000)

# %%
manager['refuges'][0]
# Out:
# {'accessible_hiver': False,
#  'altitude': 2151,
#  'altitude_m': 1570,
#  'capacite': 75,
#  'coordonnees': {'latitude': 42.8025, 'longitude': -0.1417},
#  'nom': 'Refuge des Oulettes de Gaube',
#  'services': ['dortoir', 'repas', 'eau potable']}

# %%
manager.save()
# Out:
# 2025-12-29 18:37:11   interactiveshell.py:3639  INFO     Save jsonmanager_refuge.json in 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data'

# %%
new_manager = manager.copy(DIR_EXAMPLES_GENERATED)
# Out:
# 2025-12-29 18:37:11          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# 2025-12-29 18:37:11          checktype.py:118   DEBUG    Change the parameter destination of copy with a 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated' value and a type <class 'pathlib._local.WindowsPath'> to type <class 'webspirit.classes.tools.typing.StrPath'>
# 2025-12-29 18:37:11                In[13]:1     INFO     Copy 'jsonmanager_refuge.json' in '..\..\generated' directory
# 2025-12-29 18:37:11            manager.py:69    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:108   DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated'
# 2025-12-29 18:37:11          checktype.py:93    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:78    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:108   DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated'
# 2025-12-29 18:37:11            manager.py:99    DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated\jsonmanager_refuge.json'
# 2025-12-29 18:37:11            manager.py:108   DEBUG    Skip existing test for 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated'
# 2025-12-29 18:37:11          checktype.py:93    INFO     Load 'jsonmanager_refuge.json' in '..\..\generated' directory

# %%
new_manager['refuges'][0]
# Out:
# {'accessible_hiver': False,
#  'altitude': 2151,
#  'altitude_m': 1570,
#  'capacite': 75,
#  'coordonnees': {'latitude': 42.8025, 'longitude': -0.1417},
#  'nom': 'Refuge des Oulettes de Gaube',
#  'services': ['dortoir', 'repas', 'eau potable']}

# %%
new_manager.delete()
# Out:
# 2025-12-29 18:37:11   interactiveshell.py:3639  INFO     Delete 'jsonmanager_refuge.json' in 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\generated' directory

# %% [markdown]
# # load, save and delete json

# %%
manager = load_json(path)
# Out:
# 2025-12-29 18:37:11          checktype.py:118   INFO     Load 'jsonmanager_refuge.json' in '..\..\data' directory

# %%
type(manager)
# Out:
# webspirit.classes.tools.manager.JsonManager

# %%
from random import randint

manager['refuges'][0]['altitude_m'] = randint(0, 3000)

# %%
type(manager)
# Out:
# webspirit.classes.tools.manager.JsonManager

# %%
save_json(manager)
# Out:
# 2025-12-29 18:37:11   interactiveshell.py:3699  INFO     Save jsonmanager_refuge.json in 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\examples\data'

# %%
# delete_json(path)
