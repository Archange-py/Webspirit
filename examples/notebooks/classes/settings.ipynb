# %% [markdown]
# # [*settings.py*](../../../src/webspirit/config/settings.py)
#
# ***

# %%
from webspirit.config.settings import (
    __all__,

    ConfigManager,
    IPythonConfig,

    SETTINGS,
    INTERACTIVE
)
# Out:
# 2026-01-11 15:02:18                 In[1]:1     DEBUG    Init dir '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:02:18                 In[1]:1     DEBUG    Found checktype, contexterror, csvmanager, manager, typing modules and 0 directory in '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:02:19           settings.py:8     WARNING  Failed to load one of these modules : checktype, contexterror, csvmanager, manager, typing
# 2026-01-11 15:02:19   interactiveshell.py:3699  DEBUG    Init dir '..\..\..\src\webspirit\classes'
# 2026-01-11 15:02:19   interactiveshell.py:3699  DEBUG    Found webfiles modules and tools directory in '..\..\..\src\webspirit\classes'
# 2026-01-11 15:02:19                 In[1]:1     DEBUG    Get attribute tools in ..\..\..\src\webspirit\classes\tools
# 2026-01-11 15:02:19          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# ...

# %%
__all__
# Out:
# ['Parameter', 'ConfigManager', 'IPythonConfig', 'SETTINGS', 'INTERACTIVE']

# %% [markdown]
# ## Settings

# %%
type(SETTINGS)
# Out:
# webspirit.config.settings.ConfigManager

# %%
SETTINGS
# Out:
# {
#   "language": "en",
#   "dark_mode": false,
#   "theme": "light",
#   "username": "DefaultUser",
#   "launch_animation": true,
#   "path_FFmpeg": "C:\\Users\\Blondel\\Documents\\Programmation\\Langage\\Python\\Projects\\PyForge\\plugins\\Webspirit\\src\\webspirit\\resources\\FFmpeg\\bin\\ffmpeg.exe"
# }

# %%
type(SETTINGS['dark_mode'])
# Out:
# bool

# %%
from random import choice

SETTINGS['language'] = choice(SETTINGS.config['language'].get_options())

SETTINGS.save()
# Out:
# 2026-01-11 15:02:19            manager.py:53    INFO     Load 'languages.json' in '.' directory
# 2026-01-11 15:02:19   interactiveshell.py:3699  INFO     Save user.json in '.'

# %%
SETTINGS
# Out:
# {
#   "language": "it",
#   "dark_mode": false,
#   "theme": "light",
#   "username": "DefaultUser",
#   "launch_animation": true,
#   "path_FFmpeg": "C:\\Users\\Blondel\\Documents\\Programmation\\Langage\\Python\\Projects\\PyForge\\plugins\\Webspirit\\src\\webspirit\\resources\\FFmpeg\\bin\\ffmpeg.exe"
# }

# %% [markdown]
# ## Interactivity

# %%
INTERACTIVE
# Out:
# 2026-01-11 15:02:19            manager.py:53    INFO     Load 'theme.json' in '.' directory
# ...

# %%
SETTINGS
# Out:
# {
#   "language": "it",
#   "dark_mode": false,
#   "theme": "light",
#   "username": "DefaultUser",
#   "launch_animation": true,
#   "path_FFmpeg": "C:\\Users\\Blondel\\Documents\\Programmation\\Langage\\Python\\Projects\\PyForge\\plugins\\Webspirit\\src\\webspirit\\resources\\FFmpeg\\bin\\ffmpeg.exe"
# }

# %%
SETTINGS.reset('path_FFmpeg')
# Out:
# 2026-01-11 15:02:19                In[10]:1     INFO     Save user.json in '.'
