# %% [markdown]
# # [*introspection.py*](../../config/introspection.py)
#
# ***

# %%
from webspirit.config.introspection import (
    __all__,
    show,
    links_from_cell,
    tree_directory
)
# Out:
# 2025-12-22 23:54:01                 In[1]:1     DEBUG    Init dir '..\..\classes\tools'
# 2025-12-22 23:54:01                 In[1]:1     DEBUG    Found checktype, contexterror, csvmanager, jsonmanager modules and 0 directory in '..\..\classes\tools'
# 2025-12-22 23:54:02   interactiveshell.py:3699  DEBUG    Init dir '..\..\classes'
# 2025-12-22 23:54:02   interactiveshell.py:3699  DEBUG    Found webfiles modules and tools directory in '..\..\classes'
# 2025-12-22 23:54:02                 In[1]:1     DEBUG    Get attribute tools in ..\..\classes\tools

# %%
__all__
# Out:
# ['show', 'links_from_cell', 'tree_directory']

# %% [markdown]
# ## show
# ***

# %%
from webspirit.config.constants import ROOT_DIR

# %%
show(ROOT_DIR)
# Out:
# str  : C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit
# repr : WindowsPath('C:/Users/Blondel/Documents/Programmation/Langage/Python/Projects/PyForge/plugins/Webspirit')

# %% [markdown]
# ## links_from_cell
# ***

# %% [markdown]
# ## tree_directory
# ***

# %%
print(tree_directory(r"../classes"))
# Out:
# 2025-12-22 23:54:03          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# 2025-12-22 23:54:03          checktype.py:118   DEBUG    Change the parameter root of tree_directory with a '../classes' value and a type <class 'str'> to type <class 'webspirit.classes.webfiles.StrPath'>
# 2025-12-22 23:54:03          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# 2025-12-22 23:54:03          checktype.py:118   DEBUG    Change the parameter ignore of tree_directory with a 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\.gitignore' value and a type <class 'pathlib._local.WindowsPath'> to type <class 'webspirit.classes.webfiles.StrPath'>
# classes
# ├── checktype.ipynb
# ├── introspection.ipynb
# ├── jsonmanager.ipynb
# └── webfiles.ipynb

# %%
print(tree_directory(show_var=True, show_doc=True))
# Out:
# 2025-12-22 23:54:03          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# 2025-12-22 23:54:03          checktype.py:118   DEBUG    Change the parameter root of tree_directory with a 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit' value and a type <class 'pathlib._local.WindowsPath'> to type <class 'webspirit.classes.webfiles.StrPath'>
# 2025-12-22 23:54:03          checktype.py:91    WARNING  ValueError - list.remove(x): x not in list
# 2025-12-22 23:54:03          checktype.py:118   DEBUG    Change the parameter ignore of tree_directory with a 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\.gitignore' value and a type <class 'pathlib._local.WindowsPath'> to type <class 'webspirit.classes.webfiles.StrPath'>
# ...
