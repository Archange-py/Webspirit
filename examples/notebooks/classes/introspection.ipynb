# %% [markdown]
# # [*introspection.py*](../../../src/webspirit/config/introspection.py)
#
# ***

# %%
from webspirit.config.constants import DIR_EXAMPLES_NOTEBOOKS, ROOT_DIR

# %%
from webspirit.classes.tools.typing import StrPath, HyperLink
# Out:
# 2026-01-11 15:01:10   interactiveshell.py:3699  DEBUG    Init dir '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:01:10   interactiveshell.py:3699  DEBUG    Found checktype, contexterror, csvmanager, manager, typing modules and 0 directory in '..\..\..\src\webspirit\classes\tools'
# 2026-01-11 15:01:11                 In[2]:1     WARNING  Failed to load one of these modules : checktype, contexterror, csvmanager, manager, typing
# 2026-01-11 15:01:11   interactiveshell.py:3639  DEBUG    Init dir '..\..\..\src\webspirit\classes'
# 2026-01-11 15:01:11   interactiveshell.py:3639  DEBUG    Found webfiles modules and tools directory in '..\..\..\src\webspirit\classes'
# 2026-01-11 15:01:11   interactiveshell.py:3699  DEBUG    Get attribute tools in ..\..\..\src\webspirit\classes\tools

# %%
from webspirit.config.introspection import (
    __all__,
    show,
    links_from_cell,
    tree_directory
)

# %%
__all__
# Out:
# ['show', 'links_from_cell', 'tree_directory']

# %% [markdown]
# ## show
# ***

# %%
show(ROOT_DIR)
# Out:
# str  : C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit
# repr : WindowsPath('C:/Users/Blondel/Documents/Programmation/Langage/Python/Projects/PyForge/plugins/Webspirit')

# %% [markdown]
# ## links_from_cell
# ***

# %% [raw]
# https://youtu.be/019289
# https://youtu.be/099283
# https://youtu.be/029294

# %%
ipynb_path: StrPath = StrPath(DIR_EXAMPLES_NOTEBOOKS / 'classes/introspection.ipynb')

# %%
links_from_cell(ipynb_path, index=8, type=HyperLink)
# Out:
# 2026-01-11 15:01:11            manager.py:53    INFO     Création d'un fichier vide introspection.json, car il n'existe pas
# 2026-01-11 15:01:11            manager.py:53    INFO     Load 'introspection.json' in '.' directory
# 2026-01-11 15:01:11                 In[7]:1     INFO     Save introspection.json in '.'
# 2026-01-11 15:01:11                 In[7]:1     INFO     Delete 'introspection.json' in '.' directory
# [HyperLink('https://youtu.be/019289'),
#  HyperLink('https://youtu.be/099283'),
#  HyperLink('https://youtu.be/029294')]

# %% [markdown]
# ## tree_directory
# ***

# %%
print(tree_directory(StrPath('.')))
# Out:
# classes
# ├── checktype.ipynb
# ├── introspection.ipynb
# ├── manager.ipynb
# ├── settings.ipynb
# └── typing.ipynb

# %%
print(tree_directory(show_var=True, show_doc=True))
# Out:
# 2026-01-11 15:01:11          checktype.py:70    WARNING  ValueError - list.remove(x): x not in list
# 2026-01-11 15:01:11      introspection.py:168   DEBUG    Change the parameter directory of get_entries with a 'C:\Users\Blondel\Documents\Programmation\Langage\Python\Projects\PyForge\plugins\Webspirit\src\webspirit' value and a type <class 'pathlib._local.WindowsPath'> to type <class 'webspirit.classes.tools.typing.StrPath'>
# 2026-01-11 15:01:11      introspection.py:149   WARNING  ValueError: Bookmarks doit définir une extension, exemple: class JsonManager(BaseManager, extension='.json') - An error was occurred while tried to get the '__all__' variable of the 'webspirit.addons.bookmarks' library
# 2026-01-11 15:01:11      introspection.py:159   WARNING  ValueError: Bookmarks doit définir une extension, exemple: class JsonManager(BaseManager, extension='.json') - An error was occurred while tried to get the '__doc__' variable of the 'webspirit.addons.bookmarks' library
# ...
