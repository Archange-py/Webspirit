# %% [markdown]
# # Files and Folder Constants
# ***

# %%
from webspirit.config.dynamic_constants import PATH_LOGS, PATH_FFMPEG

# Ou bien

from webspirit.config.constants import PATH_LOGS, PATH_FFMPEG

# %%
# PATH_LOGS

# %%
# PATH_FFMPEG
